# %%
import os
import json
import torch
import torch.nn as nn
import pandas as pd
import matplotlib.pyplot as plt

# %%
os.chdir('C:/Users/amitx/Documents/Amit/Projects_Python/explainablity-transformer')

# %%
path_a='./nlp/results/06_27_2022__02_48_40'

# %%
arr_a_instance_macro= []
arr_a_instance_micro= []

for k in range(5,85,5):
    path_json = path_a+f'./nlp/results/metrics_results/metrics_results_temp_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_a_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_a_instance_micro.append(data['token_prf']['instance_micro']['f1'])

arr_b_instance_macro= []
arr_b_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results_original/metrics_results_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_b_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_b_instance_micro.append(data['token_prf']['instance_micro']['f1'])

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_macro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_macro,label='model_b')
plt.legend()
plt.title('token_prf -instance_macro - f1')
plt.show()

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_micro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_micro,label='model_b')
plt.legend()
plt.title('token_prf -instance_micro - f1')
plt.show()

# %%
arr_a_instance_macro= []
arr_a_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results/metrics_results_temp_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_a_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_a_instance_micro.append(data['token_prf']['instance_micro']['f1'])

arr_b_instance_macro= []
arr_b_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results_original/metrics_results_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_b_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_b_instance_micro.append(data['token_prf']['instance_micro']['f1'])

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_macro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_macro,label='model_b')
plt.legend()
plt.title('token_prf -instance_macro - f1')
plt.show()

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_micro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_micro,label='model_b')
plt.legend()
plt.title('token_prf -instance_micro - f1')
plt.show()

# %%
arr_a_instance_macro= []
arr_a_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results/metrics_results_temp_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_a_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_a_instance_micro.append(data['token_prf']['instance_micro']['f1'])

arr_b_instance_macro= []
arr_b_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results_original/metrics_results_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_b_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_b_instance_micro.append(data['token_prf']['instance_micro']['f1'])

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_macro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_macro,label='model_b')
plt.legend()
plt.title('token_prf -instance_macro - f1')
plt.show()

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_micro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_micro,label='model_b')
plt.legend()
plt.title('token_prf -instance_micro - f1')
plt.show()

# %%
arr_a_instance_macro= []
arr_a_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results/metrics_results_temp_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_a_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_a_instance_micro.append(data['token_prf']['instance_micro']['f1'])

arr_b_instance_macro= []
arr_b_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results_original/metrics_results_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_b_instance_macro.append(data['token_prf']['instance_macro']['f1'])
    arr_b_instance_micro.append(data['token_prf']['instance_micro']['f1'])

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_macro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_macro,label='model_b')
plt.legend()
plt.title('token_prf -instance_macro - f1')
plt.show()

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_micro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_micro,label='model_b')
plt.legend()
plt.title('token_prf -instance_micro - f1')
plt.show()

# %%
data
# Out:
# {'iou_scores': [{'macro': {'f1': 0.008034675532569074,
#     'p': 0.0045625,
#     'r': 0.03362137438199678},
#    'micro': {'f1': 0.008037877119577186,
#     'p': 0.0045625,
#     'r': 0.03373382624768946},
#    'threshold': 0.5}],
#  'rationale_prf': {'instance_macro': {'f1': 0.0020022238602958116,
#    'p': 0.0011875000000000004,
#    'r': 0.008046287890608376},
#   'instance_micro': {'f1': 0.0020920502092050207,
#    'p': 0.0011875,
#    'r': 0.00878003696857671}},
#  'token_prf': {'instance_macro': {'f1': 0.25005390369750885,
#    'p': 0.39656250000000026,
#    'r': 0.21129471394277005},
#   'instance_micro': {'f1': 0.23662129405183666,
#    'p': 0.3965625,
#    'r': 0.16861546638320488}}}

# %%
arr_a_instance_macro= []
arr_a_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results/metrics_results_temp_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_a_instance_macro.append(data['iou_scores'][0]['macro']['f1'])
    arr_a_instance_micro.append(data['iou_scores'][0]['micro']['f1'])

arr_b_instance_macro= []
arr_b_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results_original/metrics_results_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_b_instance_macro.append(data['iou_scores'][0]['macro']['f1'])
    arr_b_instance_micro.append(data['iou_scores'][0]['micro']['f1'])

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_macro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_macro,label='model_b')
plt.legend()
plt.title('iou_scores -macro - f1')
plt.show()

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_micro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_micro,label='model_b')
plt.legend()
plt.title('iou_scores -macro - f1')
plt.show()

# %%
arr_a_instance_macro= []
arr_a_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results/metrics_results_temp_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_a_instance_macro.append(data['rationale_prf']['instance_macro']['f1'])
    arr_a_instance_micro.append(data['rationale_prf']['instance_micro']['f1'])

arr_b_instance_macro= []
arr_b_instance_micro= []

for k in range(5,85,5):
    path_json = f'./nlp/results/metrics_results_original/metrics_results_{k}.json'
    f = open(path_json)
    data = json.load(f)
    arr_b_instance_macro.append(data['rationale_prf']['instance_macro']['f1'])
    arr_b_instance_micro.append(data['rationale_prf']['instance_micro']['f1'])

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_macro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_macro,label='model_b')
plt.legend()
plt.title('rationale_prf -instance_macro - f1')
plt.show()

plt.figure()
plt.plot(range(5,85,5),arr_a_instance_micro,label='model_a')
plt.plot(range(5,85,5),arr_b_instance_micro,label='model_b')
plt.legend()
plt.title('rationale_prf -instance_micro - f1')
plt.show()

# %%
str_a = 'nlp/bert_models/movies/ours/identifier_results_k.json'

# %%
results_arr = []
for k in range(5,85,5):
    k_json = f'{k}.json'
    str_a = str_a.split('identifier_results_')[0]+'identifier_results_'+k_json
    print(str_a)
# Out:
# nlp/bert_models/movies/ours/identifier_results_5.json
# nlp/bert_models/movies/ours/identifier_results_10.json
# nlp/bert_models/movies/ours/identifier_results_15.json
# nlp/bert_models/movies/ours/identifier_results_20.json
# nlp/bert_models/movies/ours/identifier_results_25.json
# nlp/bert_models/movies/ours/identifier_results_30.json
# nlp/bert_models/movies/ours/identifier_results_35.json
# nlp/bert_models/movies/ours/identifier_results_40.json
# nlp/bert_models/movies/ours/identifier_results_45.json
# nlp/bert_models/movies/ours/identifier_results_50.json
# nlp/bert_models/movies/ours/identifier_results_55.json
# nlp/bert_models/movies/ours/identifier_results_60.json
# nlp/bert_models/movies/ours/identifier_results_65.json
# nlp/bert_models/movies/ours/identifier_results_70.json
# nlp/bert_models/movies/ours/identifier_results_75.json
# nlp/bert_models/movies/ours/identifier_results_80.json
